# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.get_dataset_names()  #Default datasets in seaborn
df=sns.load_dataset('tips')
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
df.describe
# Out:
# (244, 7)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# ...

# %%
from numpy._core import numerictypes
# df['total_bill']
# df['tip']
# df[['total_bill','tip']]
# df.iloc[:5]
# df.loc[df['sex']=='Female']
df.loc[(df['day']=='Sat') & (df['time']=='Dinner')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
df['tips_percentage']=df['tip']/df['total_bill']*100  #New column created by performing operations on existing columns
df['is_weekend']=df['day'].isin(['Sat','Sun'])

# %%
df2=df.groupby('day')['tip'].mean()   #Performing aggregation operations on the dataframe
df2
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
df3= df.groupby(['tip','time']).agg(
    t_mean=('tip','mean'),
    t_sum=('tip','sum'),
    t_median=('tip','median'),
    n=('tip','count')
)

df3


sns.histplot(data=df,x='total_bill',bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df['tips_percentage']=df['tip']/df['total_bill']*100 
sns.boxplot(data=df,x='day',y='tips_percentage')
# Out:
# <Axes: xlabel='day', ylabel='tips_percentage'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df4=sns.load_dataset('titanic')

m_value=df.isna().mean()

# %%
df4=sns.load_dataset('titanic')

m_value=df4.isna().sum().sort_values(ascending=False)
sns.barplot(x=m_value.index,y=m_value.values)
# Out:
# <Axes: xlabel='None'>

# %%
sns.countplot(data=df4,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>
