# %%
Num=5
num=5
print(Num)
print(num)


Num=10
STUDENT_NAME="Ritik Raushan"
studentName="Raushan Ritik"
StudentName="RR"
print(Num)
print(STUDENT_NAME)
print(studentName)
print(StudentName)

num1=10
print(num1, 'is of type', type(num1))
# Out:
# 5
# 5
# 10
# Ritik Raushan
# Raushan Ritik
# RR
# 10 is of type <class 'int'>

# %%
import array as arr
a=arr.array('i',[1,2,3,4,5])
print(a)
print('first element:', a[0])
print('second element:', a[1])
print('last element:', a[-1])
# Out:
# array('i', [1, 2, 3, 4, 5])
# first element: 1
# second element: 2
# last element: 5

# %%
# slicing concept
numbers_list=[1,2,3,4,5,6,7,8,9]
print(numbers_list[2:5])
print(numbers_list[:4])
print(numbers_list[5:])
print(numbers_list[:])
# Out:
# [3, 4, 5]
# [1, 2, 3, 4]
# [6, 7, 8, 9]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
